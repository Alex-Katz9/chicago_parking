# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

pd.set_option('display.max_columns', 500)

# %%
with open('parking_data.pickle','rb') as read_file:
    data = pickle.load(read_file)

# %%
data.head()
# Out:
#    ticket_number           issue_date violation_location  \
# 0       35125343  2001-03-02 18:50:00       2551 W DEVON
# 1       32807228  2000-09-21 21:45:00   633 E SOLIDARITY
# 2     9061102579  1999-10-08 07:57:00     1975 E 73RD ST
# 3       32807221  2000-09-21 21:18:00   633 E SOLIDARITY
# 4       33939512  2000-09-21 21:20:00     835 N MICHIGAN
#
#                                 license_plate_number license_plate_state  \
# 0  b1179a3c9992b7985db5ebe39d9e507c6c6e573e6ed332...                  IL
# 1  c3f0ddfbd8ee6628578e9c302e0c4d4a24aa5b0fe376f7...                  TN
# 2  e943fd42d5c696f249032b8e18ebe75859f3ce575d12d4...                  IL
# 3  351856bd93281b32c9c66e4c3cd623e0a58a981bd93828...                  IA
# 4  4c5958c866f6c83037fa29eea8a7d2a05f77bd40eee23b...                  KY
#
#   license_plate_type    zipcode violation_code  \
# 0                PAS  000000000       0964100C
# 1                PAS  000000000       0964190A
# 2                PAS  606280000       0964150B
# 3                PAS  000000000       0964190A
# 4                PAS  608050000       0964150B
#
#                       violation_description unit unit_description  \
# 0      BLOCK ACCESS/ALLEY/DRIVEWAY/FIRELANE   16              CPD
# 1  EXP. METER NON-CENTRAL BUSINESS DISTRICT   24              CPD
# 2       PARKING/STANDING PROHIBITED ANYTIME  498              DOF
# 3  EXP. METER NON-CENTRAL BUSINESS DISTRICT   24              CPD
# 4       PARKING/STANDING PROHIBITED ANYTIME   18              CPD
#
#   vehicle_make  fine_level1_amount  fine_level2_amount  current_amount_due  \
# 0         SATR                  50                 100                 0.0
# 1         ACUR                  30                  60                30.0
# 2         CHRY                  30                  60                 0.0
# 3         NISS                  30                  60                30.0
# 4         FORD                  50                 100                 0.0
#
#    total_payments ticket_queue    ticket_queue_date notice_level  \
# 0            50.0         Paid  2001-03-09 00:00:00          NaN
# 1             0.0       Define  2000-09-28 00:00:00          NaN
# 2            30.0         Paid  2003-01-10 00:00:00          NaN
# 3             0.0       Define  2000-09-28 00:00:00          NaN
# 4            50.0    Dismissed  2001-10-26 00:00:00          NaN
#
#    notice_number hearing_disposition officer             normalized_address  \
# 0              0                 NaN   12511      2500 w devon, Chicago, IL
# 1              0                 NaN   15985  600 e solidarity, Chicago, IL
# 2              0                 NaN     178    1900 e 73rd st, Chicago, IL
# 3              0                 NaN   15985  600 e solidarity, Chicago, IL
# 4              0          Not Liable    3777    800 n michigan, Chicago, IL
#
#    year  month  hour  ward  tract_id  blockgroup_geoid  community_area_number  \
# 0  2001      3    18  50.0   20602.0      1.703102e+11                    2.0
# 1  2000      9    21   4.0  330100.0      1.703133e+11                   33.0
# 2  1999     10     7   5.0  430500.0      1.703143e+11                   43.0
# 3  2000      9    21   4.0  330100.0      1.703133e+11                   33.0
# 4  2000      9    21   NaN       NaN               NaN                    NaN
#
#   community_area_name  geocode_accuracy geocode_accuracy_type  \
# 0          WEST RIDGE               1.0               rooftop
# 1     NEAR SOUTH SIDE               1.0   range_interpolation
# 2         SOUTH SHORE               1.0               rooftop
# 3     NEAR SOUTH SIDE               1.0   range_interpolation
# 4                 NaN               NaN                   NaN
#
#                        geocoded_address  geocoded_lng  geocoded_lat
# 0   2500 W Devon Ave, Chicago, IL 60659    -87.692567     41.997949
# 1  600 Solidarity Dr, Chicago, IL 60605    -87.613374     41.865965
# 2     1900 E 73rd St, Chicago, IL 60649    -87.578981     41.762668
# 3  600 Solidarity Dr, Chicago, IL 60605    -87.613374     41.865965
# 4                                   NaN           NaN           NaN

# %%
data['code'] = [code[:6] for code in data['zipcode']]

# %%
import re

# %%
sixosix = data[data['zipcode'].str.match('^606.*')== True]

# %%
sixosix['code'] = [code[:5] for code in sixosix['zipcode']]
sixosix = sixosix[sixosix.code != 606]
# Out:
# <ipython-input-51-6a848b42e1e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sixosix['code'] = [code[:5] for code in sixosix['zipcode']]

# %%
zip_freq = sixosix.code.value_counts()/len(sixosix)
zip_freq
# Out:
# dtype('float64')

# %%
sixosix.code.value_counts().sort_values(ascending=True).head(50)
# Out:
# 606        1
# 60683      1
# 60698      2
# 60682      2
# 60696      4
# 60688      5
# 60689      6
# 60686      8
# 60671      8
# 60679      8
# 60697      9
# 60663     10
# 60699     13
# 60674     13
# 60669     14
# 60678     14
# 60694     14
# 60687     15
# 60693     17
# 60665     18
# 60685     19
# 60672     19
# 60667     19
# 60691     22
# 60681     23
# 60677     23
# 60662     23
# 60675     23
# 60695     24
# 60676     25
# 60668     25
# 60670     25
# 60673     28
# 60684     28
# 60600     31
# 60664     35
# 60690     88
# 60642    118
# 60658    119
# 60654    199
# 60680    200
# 60648    229
# 60603    250
# 60650    316
# 60604    341
# 60635    347
# 60602    510
# 60627    542
# 60633    738
# 60606    785
# Name: code, dtype: int64

# %%
sixosix.code.value_counts().sort_values(ascending=False).head(50)
# Out:
# 60622    18202
# 60614    18197
# 60657    16686
# 60618    15880
# 60647    15667
# 60640    13901
# 60623    13051
# 60625    12981
# 60651    12468
# 60639    11830
# 60613    11265
# 60620    10801
# 60619    10759
# 60644    10459
# 60617    10427
# 60629    10385
# 60616    10093
# 60626     9864
# 60610     9811
# 60608     9657
# 60628     9618
# 60649     9040
# 60660     8904
# 60615     8471
# 60624     8404
# 60609     8048
# 60641     7980
# 60607     7851
# 60659     7549
# 60632     7383
# 60637     7212
# 60645     6437
# 60612     6334
# 60643     5923
# 60636     5809
# 60634     5688
# 60653     4968
# 60630     4965
# 60621     4890
# 60611     4324
# 60666     4084
# 60652     3513
# 60638     3321
# 60646     3124
# 60605     2561
# 60656     2331
# 60631     1760
# 60601     1336
# 60655     1275
# 60661      900
# Name: code, dtype: int64

# %%
zip_counts = sixosix.code.value_counts().reset_index()
zip_counts.rename(columns={'index':'Zipcode','code':'Frequency'},inplace=True)
zip_counts
# Out:
#    Zipcode  Frequency
# 0    60622      18202
# 1    60614      18197
# 2    60657      16686
# 3    60618      15880
# 4    60647      15667
# ..     ...        ...
# 95   60696          4
# 96   60698          2
# 97   60682          2
# 98   60683          1
# 99     606          1
#
# [100 rows x 2 columns]

# %%
zip_counts.to_csv(r'C:\Users\ejfel\OneDrive\Desktop\parking_zips.csv',index=False)

# %%
plt.hist(sixosix.code)
plt.show();

# %%
data.zipcode.fillna(0,inplace=True)
# data.zipcode.astype('int32')
# data.zipcode.sort_values(by=['zipcode'],ascending=True)
data.zipcode.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-086e18e0fabb> in <module>
#       2 # data.zipcode.astype('int32')
#       3 # data.zipcode.sort_values(by=['zipcode'],ascending=True)
# ----> 4 data.zipcode.astype('int32')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
data[data.zipcode != '000000000'].zipcode.value_counts().tail(50)
# Out:
# 601761833      1
# 605652745      1
# 606472443      1
# 620169746      1
# 608271639      1
# 600624421      1
# 605360000.0    1
# 606442523      1
# 600254341      1
# 606121722      1
# 600442158      1
# 606144067      1
# 604251474      1
# 50060          1
# 606511853      1
# 601151416      1
# 604193800      1
# 606131712      1
# 606441949      1
# 604093552      1
# 601533320      1
# 604611424      1
# 604221041      1
# 606561449      1
# 604474501      1
# 601261968      1
# 601376336      1
# 600468915      1
# 600771703      1
# 607072944      1
# 601335264      1
# 601034709.0    1
# 606301308      1
# 62987          1
# 600763872      1
# 606473532      1
# 606133713      1
# 600044606      1
# 606143651.0    1
# 606493609      1
# 601877425      1
# 615713153      1
# 605341942      1
# 600154432      1
# 606223149      1
# 31906          1
# 606232465      1
# 600772520.0    1
# 601032335      1
# 605421524      1
# Name: zipcode, dtype: int64
